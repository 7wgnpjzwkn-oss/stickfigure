# %% [markdown]
# <a href="https://colab.research.google.com/github/7wgnpjzwkn-oss/stickfigure/blob/main/Untitled56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bpy
import math
import mathutils
import os

# ==========================================
# 1. SETUP ENVIRONMENT & CLEAN SCENE
# ==========================================
if bpy.context.object and bpy.context.object.mode != 'OBJECT':
    bpy.ops.object.mode_set(mode='OBJECT')

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete()

scene = bpy.context.scene
scene.frame_start = 1
scene.frame_end = 160
scene.frame_current = 1

# Configure engine to use Nodes
scene.render.engine = 'CYCLES'

# Add standard Camera
bpy.ops.object.camera_add(location=(0, -12, 2.5), rotation=(math.radians(82), 0, 0))
camera = bpy.context.object
scene.camera = camera

# Add a Light source
bpy.ops.object.light_add(type='SUN', location=(5, -5, 10))
sun = bpy.context.object
sun.data.energy = 2.0

# Add a ground plane
bpy.ops.mesh.primitive_plane_add(size=30, location=(0, 0, 0))

# ==========================================
# 2. BUILD THE HIGH-FIDELITY STICK FIGURE
# ==========================================
root_z_height = 1.9

# Root controller Empty
bpy.ops.object.empty_add(type='PLAIN_AXES', location=(6, 0, root_z_height))
root = bpy.context.object
root.name = "Stick_Root"

# Torso
bpy.ops.mesh.primitive_cylinder_add(radius=0.06, depth=1.2, location=(0, 0, 0))
torso = bpy.context.object
torso.name = "Torso"
torso.parent = root
torso.location = (0, 0, 0)

# Head
bpy.ops.mesh.primitive_uv_sphere_add(radius=0.3, location=(0, 0, 0.9))
head = bpy.context.object
head.name = "Head"
head.parent = torso

# Shoulders Cross-Bar
bpy.ops.mesh.primitive_cylinder_add(radius=0.04, depth=0.6, location=(0, 0, 0.5))
shoulders = bpy.context.object
shoulders.name = "Shoulders"
shoulders.parent = torso
shoulders.rotation_euler = (0, math.radians(90), 0)

# Hips Cross-Bar
bpy.ops.mesh.primitive_cylinder_add(radius=0.05, depth=0.36, location=(0, 0, -0.6))
hips = bpy.context.object
hips.name = "Hips"
hips.parent = torso
hips.rotation_euler = (0, math.radians(90), 0)

# Component factory for limbs (pivots set to top joint origins)
def create_limb(name, parent, local_position, length=1.0, radius=0.04):
    bpy.ops.mesh.primitive_cylinder_add(radius=radius, depth=length, location=(0, 0, 0))
    limb = bpy.context.object
    limb.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.transform.translate(value=(0, 0, -length / 2))
    bpy.ops.object.mode_set(mode='OBJECT')

    limb.parent = parent
    limb.location = local_position
    return limb

def attach_hand(name, parent, local_position):
    bpy.ops.mesh.primitive_uv_sphere_add(radius=0.07, location=(0, 0, 0))
    hand = bpy.context.object
    hand.name = name
    hand.parent = parent
    hand.location = local_position
    return hand

def attach_foot(name, parent, local_position):
    bpy.ops.mesh.primitive_cube_add(size=1, location=(0, 0, 0))
    foot = bpy.context.object
    foot.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.transform.resize(value=(0.04, 0.12, 0.03))
    bpy.ops.transform.translate(value=(0, 0.08, 0))
    bpy.ops.object.mode_set(mode='OBJECT')

    foot.parent = parent
    foot.location = local_position
    return foot

# Upper Arms, Forearms, and Hands
upper_arm_l = create_limb("Upper_Arm_L", torso, (-0.3, 0, 0.5), length=0.45)
forearm_l   = create_limb("Forearm_L", upper_arm_l, (0, 0, -0.45), length=0.45)
hand_l      = attach_hand("Hand_L", forearm_l, (0, 0, -0.45))

upper_arm_r = create_limb("Upper_Arm_R", torso, (0.3, 0, 0.5), length=0.45)
forearm_r   = create_limb("Forearm_R", upper_arm_r, (0, 0, -0.45), length=0.45)
hand_r      = attach_hand("Hand_R", forearm_r, (0, 0, -0.45))

# Lower Body segments
leg_segment_length = 0.65
thigh_l = create_limb("Thigh_L", torso, (-0.18, 0, -0.6), length=leg_segment_length)
shin_l  = create_limb("Shin_L", thigh_l, (0, 0, -leg_segment_length), length=leg_segment_length)
foot_l  = attach_foot("Foot_L", shin_l, (0, 0, -leg_segment_length))

thigh_r = create_limb("Thigh_R", torso, (0.18, 0, -0.6), length=leg_segment_length)
shin_r  = create_limb("Shin_R", thigh_r, (0, 0, -leg_segment_length), length=leg_segment_length)
foot_r  = attach_foot("Foot_R", shin_r, (0, 0, -leg_segment_length))

# ==========================================
# 3. PROP SETUP: SCROLL PIECES (WORLD SPACE)
# ==========================================
bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_r = bpy.context.object
scroll_roll_r.name = "Scroll_Roll_R"

bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_l = bpy.context.object
scroll_roll_l.name = "Scroll_Roll_L"

bpy.ops.mesh.primitive_cube_add(size=1)
scroll_paper = bpy.context.object
scroll_paper.name = "Scroll_Paper"

# Set up sheet geometry orientation for dynamic scaling along its local X axis
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.transform.resize(value=(1.0, 0.005, 0.36))
bpy.ops.object.mode_set(mode='OBJECT')

# ==========================================
# 3b. MATERIAL SETUP WITH SHADER NODES
# ==========================================
mat = bpy.data.materials.new(name="Scroll_Texture_Material")
mat.use_nodes = True
nodes = mat.node_tree.nodes
links = mat.node_tree.links

# Clear default generation nodes safely
nodes.clear()

# Create target texture generation pipeline
node_tex_coord = nodes.new(type='ShaderNodeTexCoord')
node_mapping   = nodes.new(type='ShaderNodeMapping')
node_texture   = nodes.new(type='ShaderNodeTexImage')
node_principled= nodes.new(type='ShaderNodeBsdfPrincipled')
node_output    = nodes.new(type='ShaderNodeOutputMaterial')





node_mapping.inputs['Scale'].default_value[0] = 0.5 # Scale X
node_mapping.inputs['Scale'].default_value[1] = 0.5 # Scale Y
node_mapping.inputs['Scale'].default_value[2] = 2.0 # Scale Z


# Position nodes logically for UI visualization readability
node_tex_coord.location  = (-600, 0)
node_mapping.location    = (-400, 0)
node_texture.location    = (-150, 0)
node_principled.location = (150, 0)
node_output.location     = (400, 0)

# Set path pointing to target JPG file assets safely
image_path = "/Users/dobbinp1/Downloads/IMGP6239_psedit.jpg"
if os.path.exists(image_path):
    try:
        img = bpy.data.images.load(image_path)
        node_texture.image = img
    except Exception as e:
        print(format(f"Image load error: {e}. Defaulting to backup grid generation."))
else:
    # Safe fallback if file target is structurally missing or renamed unexpectedly
    print(format(f"File path '{image_path}' not found. Using automatic texture generator wrapper."))
    img = bpy.data.images.new("Fallback_Grid", width=1024, height=1024)
    img.generated_type = 'GRID'
    node_texture.image = img

# Link structural nodes together cleanly
links.new(node_tex_coord.outputs['UV'], node_mapping.inputs['Vector'])
links.new(node_mapping.outputs['Vector'], node_texture.inputs['Vector'])
links.new(node_texture.outputs['Color'], node_principled.inputs['Base Color'])
links.new(node_principled.outputs['BSDF'], node_output.inputs['Surface'])

# Bind constructed material asset onto the paper sheet geometry mesh array safely
if len(scroll_paper.data.materials) == 0:
    scroll_paper.data.materials.append(mat)
else:
    scroll_paper.data.materials[0] = mat

# Rotate mapping node orientation coordinates 90 degrees if your vertical image composition requires rotation corrections
node_mapping.inputs['Rotation'].default_value[2] = math.radians(90)

# ==========================================
# 4. KINEMATIC TARGET CALCULATIONS FOR TOUCH
# ==========================================
target_alpha = math.radians(30) # Forward pitch
target_gamma = math.radians(30) # Forearm bend
eff_length = 0.45 * math.cos(target_alpha) + 0.45 * math.cos(target_alpha + target_gamma)
target_beta_r = math.asin(0.3 / eff_length)
target_beta_l = -target_beta_r

# ==========================================
# 5. ROOT PATH KEYFRAMES (FRAMES 1-160)
# ==========================================
scene.frame_set(1)
root.location = (6, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(65)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(75)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(180))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

for f in [92, 105, 125, 145, 160]:
    scene.frame_set(f)
    root.location = (0, 0, root_z_height)
    root.rotation_euler = (0, 0, math.radians(180))
    root.keyframe_insert(data_path="location")
    root.keyframe_insert(data_path="rotation_euler")

# ==========================================
# 6. UNIFIED ANIMATION & MATRIX TRACKING LOOP
# ==========================================
for frame in range(1, 161):
    scene.frame_set(frame)
    unfurl_factor = 0.0

    # --- PHASE A: WALK CYCLE (Frames 1-65) ---
    if frame <= 65:
        if frame < 55: damping = 1.0
        else: damping = 1.0 - ((frame - 55) / 10.0)

        walk_speed = 0.45
        swing = math.sin(frame * walk_speed) * math.radians(26) * damping
        thigh_cos = math.cos(frame * walk_speed)

        thigh_l.rotation_euler = (swing, 0, 0)
        thigh_r.rotation_euler = (-swing, 0, 0)
        shin_l.rotation_euler = (-max(0.0, thigh_cos) * math.radians(50) * damping, 0, 0)
        shin_r.rotation_euler = (-max(0.0, -thigh_cos) * math.radians(50) * damping, 0, 0)
        foot_l.rotation_euler = (-thigh_l.rotation_euler[0] - shin_l.rotation_euler[0], 0, 0)
        foot_r.rotation_euler = (-thigh_r.rotation_euler[0] - shin_r.rotation_euler[0], 0, 0)

        upper_arm_l.rotation_euler = (-swing, 0, 0)
        forearm_l.rotation_euler = (math.radians(20), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    # --- PHASE B: TURN TO FACE CAMERA (Frames 66-75) ---
    elif frame <= 75:
        t = (frame - 65) / 10.0
        for leg in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r]:
            leg.rotation_euler = (0, 0, 0)

        upper_arm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)
        forearm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    # --- PHASE C: THE "MOVE CLOSER" UP-AND-DOWN GESTURE (Frames 76-92) ---
    elif frame <= 92:
        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

        upper_arm_l.rotation_euler = (math.radians(45), math.radians(15), 0)
        beckon_wave = math.sin((frame - 76) * 0.8)
        forearm_l.rotation_euler = (math.radians(60) + beckon_wave * math.radians(25), 0, 0)

    # --- PHASE D: HANDS CONVERGE TO CALCULATED METRIC TOUCH POINT (Frames 93-105) ---
    elif frame <= 105:
        t = (frame - 92) / 13.0

        upper_arm_r.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(-10) + t * (target_beta_r - math.radians(-10)),
            0
        )
        forearm_r.rotation_euler = (math.radians(60) + t * (target_gamma - math.radians(60)), 0, 0)

        start_fore_l = math.radians(60) + math.sin((92 - 76) * 0.8) * math.radians(25)
        upper_arm_l.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(15) + t * (target_beta_l - math.radians(15)),
            0
        )
        forearm_l.rotation_euler = (start_fore_l + t * (target_gamma - start_fore_l), 0, 0)

    # --- PHASE E: SYMMETRIC SMOOTH HORIZONTAL UNFURL (Frames 106-125) ---
    elif frame <= 125:
        t = (frame - 105) / 20.0
        unfurl_factor = 1.0

        curr_beta_r = target_beta_r + t * (math.radians(-15) - target_beta_r)
        curr_beta_l = target_beta_l + t * (math.radians(15) - target_beta_l)

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    # --- PHASE F: PRESENTATION DISPLAY HOLD (Frames 126-145) ---
    elif frame <= 145:
        unfurl_factor = 1.0

        upper_arm_r.rotation_euler = (target_alpha, math.radians(-15), 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, math.radians(15), 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    # --- PHASE G: RE-ROLL CLOSURE SECURELY BACK TO CENTER (Frames 146-160) ---
    else:
        t = (frame - 145) / 15.0
        unfurl_factor = 1.0

        curr_beta_r = math.radians(-15) + t * (target_beta_r - math.radians(-15))
        curr_beta_l = math.radians(15) + t * (target_beta_l - math.radians(15))

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    # Commit bone rotation data
    for limb in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r, upper_arm_l, forearm_l, upper_arm_r, forearm_r]:
        limb.keyframe_insert(data_path="rotation_euler")

    # ==========================================
    # ABSOLUTE FACTOR-BASED SCROLL ENGINE
    # ==========================================
    bpy.context.view_layer.update()

    wpos_r = hand_r.matrix_world.to_translation()
    wpos_l = hand_l.matrix_world.to_translation()

    scroll_roll_r.location = wpos_r
    scroll_roll_l.location = wpos_r + unfurl_factor * (wpos_l - wpos_r)

    scroll_paper.location = (scroll_roll_r.location + scroll_roll_l.location) / 2.0
    span = (scroll_roll_l.location - scroll_roll_r.location).length
    scroll_paper.scale = (max(0.01, span), 1.0, 1.0)

    scroll_roll_r.rotation_euler = (0, 0, 0)
    scroll_roll_l.rotation_euler = (0, 0, 0)
    scroll_paper.rotation_euler = (0, 0, 0)

    for prop in [scroll_roll_r, scroll_roll_l, scroll_paper]:
        prop.keyframe_insert(data_path="location")
        prop.keyframe_insert(data_path="rotation_euler")
    scroll_paper.keyframe_insert(data_path="scale")

# ==========================================
# 7. CAMERA MOVEMENT TRACKING
# ==========================================
scene.frame_set(1)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(105)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(125)
camera.location = (0, -5.2, 2.0)
camera.keyframe_insert(data_path="location")

scene.frame_set(1)
print("Texture pipeline deployed cleanly. Image mapping linked to unrolling bounds perfectly!")
# Out:
# Texture pipeline deployed cleanly. Image mapping linked to unrolling bounds perfectly!
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_31695/1765581820.py:155: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   mat.use_nodes = True

# %%
import bpy
import math
import mathutils
import os

# ==========================================
# 1. SETUP ENVIRONMENT & CLEAN SCENE
# ==========================================
if bpy.context.object and bpy.context.object.mode != 'OBJECT':
    bpy.ops.object.mode_set(mode='OBJECT')

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete()

scene = bpy.context.scene
scene.frame_start = 1
scene.frame_end = 160
scene.frame_current = 1

scene.render.engine = 'CYCLES'

# Add standard Camera
bpy.ops.object.camera_add(location=(0, -12, 2.5), rotation=(math.radians(82), 0, 0))
camera = bpy.context.object
scene.camera = camera

# Add a Light source
bpy.ops.object.light_add(type='SUN', location=(5, -5, 10))
sun = bpy.context.object
sun.data.energy = 2.0

# Add a ground plane
bpy.ops.mesh.primitive_plane_add(size=30, location=(0, 0, 0))

# ==========================================
# 2. BUILD THE HIGH-FIDELITY STICK FIGURE
# ==========================================
root_z_height = 1.9

bpy.ops.object.empty_add(type='PLAIN_AXES', location=(6, 0, root_z_height))
root = bpy.context.object
root.name = "Stick_Root"

torso = bpy.ops.mesh.primitive_cylinder_add(radius=0.06, depth=1.2, location=(0, 0, 0))
torso = bpy.context.object
torso.name = "Torso"
torso.parent = root
torso.location = (0, 0, 0)

bpy.ops.mesh.primitive_uv_sphere_add(radius=0.3, location=(0, 0, 0.9))
head = bpy.context.object
head.name = "Head"
head.parent = torso

bpy.ops.mesh.primitive_cylinder_add(radius=0.04, depth=0.6, location=(0, 0, 0.5))
shoulders = bpy.context.object
shoulders.name = "Shoulders"
shoulders.parent = torso
shoulders.rotation_euler = (0, math.radians(90), 0)

bpy.ops.mesh.primitive_cylinder_add(radius=0.05, depth=0.36, location=(0, 0, -0.6))
hips = bpy.context.object
hips.name = "Hips"
hips.parent = torso
hips.rotation_euler = (0, math.radians(90), 0)

def create_limb(name, parent, local_position, length=1.0, radius=0.04):
    bpy.ops.mesh.primitive_cylinder_add(radius=radius, depth=length, location=(0, 0, 0))
    limb = bpy.context.object
    limb.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.transform.translate(value=(0, 0, -length / 2))
    bpy.ops.object.mode_set(mode='OBJECT')

    limb.parent = parent
    limb.location = local_position
    return limb

def attach_hand(name, parent, local_position):
    bpy.ops.mesh.primitive_uv_sphere_add(radius=0.07, location=(0, 0, 0))
    hand = bpy.context.object
    hand.name = name
    hand.parent = parent
    hand.location = local_position
    return hand

def attach_foot(name, parent, local_position):
    bpy.ops.mesh.primitive_cube_add(size=1, location=(0, 0, 0))
    foot = bpy.context.object
    foot.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.transform.resize(value=(0.04, 0.12, 0.03))
    bpy.ops.transform.translate(value=(0, 0.08, 0))
    bpy.ops.object.mode_set(mode='OBJECT')

    foot.parent = parent
    foot.location = local_position
    return foot

upper_arm_l = create_limb("Upper_Arm_L", torso, (-0.3, 0, 0.5), length=0.45)
forearm_l   = create_limb("Forearm_L", upper_arm_l, (0, 0, -0.45), length=0.45)
hand_l      = attach_hand("Hand_L", forearm_l, (0, 0, -0.45))

upper_arm_r = create_limb("Upper_Arm_R", torso, (0.3, 0, 0.5), length=0.45)
forearm_r   = create_limb("Forearm_R", upper_arm_r, (0, 0, -0.45), length=0.45)
hand_r      = attach_hand("Hand_R", forearm_r, (0, 0, -0.45))

leg_segment_length = 0.65
thigh_l = create_limb("Thigh_L", torso, (-0.18, 0, -0.6), length=leg_segment_length)
shin_l  = create_limb("Shin_L", thigh_l, (0, 0, -leg_segment_length), length=leg_segment_length)
foot_l  = attach_foot("Foot_L", shin_l, (0, 0, -leg_segment_length))

thigh_r = create_limb("Thigh_R", torso, (0.18, 0, -0.6), length=leg_segment_length)
shin_r  = create_limb("Shin_R", thigh_r, (0, 0, -leg_segment_length), length=leg_segment_length)
foot_r  = attach_foot("Foot_R", shin_r, (0, 0, -leg_segment_length))

# ==========================================
# 3. PROP SETUP: SCROLL PIECES
# ==========================================
bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_r = bpy.context.object
scroll_roll_r.name = "Scroll_Roll_R"

bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_l = bpy.context.object
scroll_roll_l.name = "Scroll_Roll_L"

# FIX 1: Use a flat Plane primitive instead of a Cube.
# A Plane possesses native 0-to-1 face UV maps out of the box.
bpy.ops.mesh.primitive_plane_add(size=1)
scroll_paper = bpy.context.object
scroll_paper.name = "Scroll_Paper"

bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
# Rotate mesh plane faces to stand up vertically facing the camera layout
bpy.ops.transform.rotate(value=math.radians(90), orient_axis='X')
# Scale mesh shape: X=1.0 width scale anchor, Z=0.36 height framing
bpy.ops.transform.resize(value=(1.0, 1.0, 0.36))
bpy.ops.object.mode_set(mode='OBJECT')

# ==========================================
# 3b. MATERIAL SETUP WITH SHADER NODES
# ==========================================
mat = bpy.data.materials.new(name="Scroll_Texture_Material")
mat.use_nodes = True
nodes = mat.node_tree.nodes
links = mat.node_tree.links
nodes.clear()

node_tex_coord = nodes.new(type='ShaderNodeTexCoord')
node_mapping   = nodes.new(type='ShaderNodeMapping')
node_texture   = nodes.new(type='ShaderNodeTexImage')
node_principled= nodes.new(type='ShaderNodeBsdfPrincipled')
node_output    = nodes.new(type='ShaderNodeOutputMaterial')

node_mapping.vector_type = 'POINT'

node_tex_coord.location  = (-600, 0)
node_mapping.location    = (-400, 0)
node_texture.location    = (-150, 0)
node_principled.location = (150, 0)
node_output.location     = (400, 0)

image_path = "/Users/dobbinp1/Downloads/IMGP6239_psedit.jpg"
if os.path.exists(image_path):
    try:
        img = bpy.data.images.load(image_path)
        node_texture.image = img
    except Exception as e:
        print(f"Image load error: {e}")
else:
    img = bpy.data.images.new("Fallback_Grid", width=1024, height=1024)
    img.generated_type = 'GRID'
    node_texture.image = img

links.new(node_tex_coord.outputs['UV'], node_mapping.inputs['Vector'])
links.new(node_mapping.outputs['Vector'], node_texture.inputs['Vector'])
links.new(node_texture.outputs['Color'], node_principled.inputs['Base Color'])
links.new(node_principled.outputs['BSDF'], node_output.inputs['Surface'])

if len(scroll_paper.data.materials) == 0:
    scroll_paper.data.materials.append(mat)
else:
    scroll_paper.data.materials[0] = mat

# Clean texture rotation matrix: standard flat orientation matching the plane mesh faces
node_mapping.inputs['Rotation'].default_value[2] = math.radians(0)

# ==========================================
# 4. KINEMATIC TARGET CALCULATIONS
# ==========================================
target_alpha = math.radians(30)
target_gamma = math.radians(30)
eff_length = 0.45 * math.cos(target_alpha) + 0.45 * math.cos(target_alpha + target_gamma)
target_beta_r = math.asin(0.3 / eff_length)
target_beta_l = -target_beta_r

# ==========================================
# 5. ROOT PATH KEYFRAMES
# ==========================================
scene.frame_set(1)
root.location = (6, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(65)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(75)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(180))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

for f in [92, 105, 125, 145, 160]:
    scene.frame_set(f)
    root.location = (0, 0, root_z_height)
    root.rotation_euler = (0, 0, math.radians(180))
    root.keyframe_insert(data_path="location")
    root.keyframe_insert(data_path="rotation_euler")

# ==========================================
# 6. UNIFIED ANIMATION & MATRIX TRACKING LOOP
# ==========================================
# Calculate peak width capacity at maximum extension frame (frame 125)
scene.frame_set(125)
bpy.context.view_layer.update()
peak_span = (hand_l.matrix_world.to_translation() - hand_r.matrix_world.to_translation()).length

for frame in range(1, 161):
    scene.frame_set(frame)
    unfurl_factor = 0.0

    if frame <= 65:
        if frame < 55: damping = 1.0
        else: damping = 1.0 - ((frame - 55) / 10.0)

        walk_speed = 0.45
        swing = math.sin(frame * walk_speed) * math.radians(26) * damping
        thigh_cos = math.cos(frame * walk_speed)

        thigh_l.rotation_euler = (swing, 0, 0)
        thigh_r.rotation_euler = (-swing, 0, 0)
        shin_l.rotation_euler = (-max(0.0, thigh_cos) * math.radians(50) * damping, 0, 0)
        shin_r.rotation_euler = (-max(0.0, -thigh_cos) * math.radians(50) * damping, 0, 0)
        foot_l.rotation_euler = (-thigh_l.rotation_euler[0] - shin_l.rotation_euler[0], 0, 0)
        foot_r.rotation_euler = (-thigh_r.rotation_euler[0] - shin_r.rotation_euler[0], 0, 0)

        upper_arm_l.rotation_euler = (-swing, 0, 0)
        forearm_l.rotation_euler = (math.radians(20), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 75:
        t = (frame - 65) / 10.0
        for leg in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r]:
            leg.rotation_euler = (0, 0, 0)

        upper_arm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)
        forearm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 92:
        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

        upper_arm_l.rotation_euler = (math.radians(45), math.radians(15), 0)
        beckon_wave = math.sin((frame - 76) * 0.8)
        forearm_l.rotation_euler = (math.radians(60) + beckon_wave * math.radians(25), 0, 0)

    elif frame <= 105:
        t = (frame - 92) / 13.0

        upper_arm_r.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(-10) + t * (target_beta_r - math.radians(-10)),
            0
        )
        forearm_r.rotation_euler = (math.radians(60) + t * (target_gamma - math.radians(60)), 0, 0)

        start_fore_l = math.radians(60) + math.sin((92 - 76) * 0.8) * math.radians(25)
        upper_arm_l.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(15) + t * (target_beta_l - math.radians(15)),
            0
        )
        forearm_l.rotation_euler = (start_fore_l + t * (target_gamma - start_fore_l), 0, 0)

    elif frame <= 125:
        t = (frame - 105) / 20.0
        unfurl_factor = t

        curr_beta_r = target_beta_r + t * (math.radians(-15) - target_beta_r)
        curr_beta_l = target_beta_l + t * (math.radians(15) - target_beta_l)

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    elif frame <= 145:
        unfurl_factor = 1.0

        upper_arm_r.rotation_euler = (target_alpha, math.radians(-15), 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, math.radians(15), 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    else:
        t = (frame - 145) / 15.0
        unfurl_factor = 1.0 - t

        curr_beta_r = math.radians(-15) + t * (target_beta_r - math.radians(-15))
        curr_beta_l = math.radians(15) + t * (target_beta_l - math.radians(15))

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    for limb in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r, upper_arm_l, forearm_l, upper_arm_r, forearm_r]:
        limb.keyframe_insert(data_path="rotation_euler")

    # ==========================================
    # ABSOLUTE FACTOR-BASED SCROLL ENGINE
    # ==========================================
    bpy.context.view_layer.update()

    wpos_r = hand_r.matrix_world.to_translation()
    wpos_l = hand_l.matrix_world.to_translation()

    scroll_roll_r.location = wpos_r
    scroll_roll_l.location = wpos_r + unfurl_factor * (wpos_l - wpos_r)

    scroll_paper.location = (scroll_roll_r.location + scroll_roll_l.location) / 2.0
    span = (scroll_roll_l.location - scroll_roll_r.location).length
    scroll_paper.scale = (max(0.01, span), 1.0, 1.0)

    # FIX 2: Anchor the image coordinates using the dynamic extension ratio.
    # By normalizing the texture mapping scale against the peak extension space width,
    # the image maps edge-to-edge across the plane faces without stretching or cropping out.
    node_mapping.inputs['Scale'].default_value = (peak_span, 1.0, 1.0)

    # Centers the image content uniformly relative to the middle of the scroll split line
    node_mapping.inputs['Location'].default_value = (-0.5 * peak_span + 0.5, 0.0, 0.0)

    scroll_roll_r.rotation_euler = (0, 0, 0)
    scroll_roll_l.rotation_euler = (0, 0, 0)
    scroll_paper.rotation_euler = (0, 0, 0)

    for prop in [scroll_roll_r, scroll_roll_l, scroll_paper]:
        prop.keyframe_insert(data_path="location")
        prop.keyframe_insert(data_path="rotation_euler")
    scroll_paper.keyframe_insert(data_path="scale")

    node_mapping.inputs['Scale'].keyframe_insert(data_path="default_value")
    node_mapping.inputs['Location'].keyframe_insert(data_path="default_value")

# ==========================================
# 7. CAMERA MOVEMENT TRACKING
# ==========================================
scene.frame_set(1)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(105)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(125)
camera.location = (0, -5.2, 2.0)
camera.keyframe_insert(data_path="location")

scene.frame_set(1)
print("Mesh converted to Flat Plane. Entire JPG window successfully revealed!")
# Out:
# Mesh converted to Flat Plane. Entire JPG window successfully revealed!
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41110/3250856509.py:150: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   mat.use_nodes = True

# %%
import bpy
import math
import mathutils
import os

# ==========================================
# 1. SETUP ENVIRONMENT & CLEAN SCENE
# ==========================================
if bpy.context.object and bpy.context.object.mode != 'OBJECT':
    bpy.ops.object.mode_set(mode='OBJECT')

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete()

scene = bpy.context.scene
scene.frame_start = 1
scene.frame_end = 160
scene.frame_current = 1

scene.render.engine = 'CYCLES'

# Add standard Camera
bpy.ops.object.camera_add(location=(0, -12, 2.5), rotation=(math.radians(82), 0, 0))
camera = bpy.context.object
scene.camera = camera

# Add a Light source
bpy.ops.object.light_add(type='SUN', location=(5, -5, 10))
sun = bpy.context.object
sun.data.energy = 2.0

# Add a ground plane
bpy.ops.mesh.primitive_plane_add(size=30, location=(0, 0, 0))

# ==========================================
# 2. ROCK LOOK GENERATOR (MATERIAL SETUP)
# ==========================================
rock_mat = bpy.data.materials.new(name="Rock_Material")
rock_mat.use_nodes = True
r_nodes = rock_mat.node_tree.nodes
r_links = rock_mat.node_tree.links
r_nodes.clear()

node_r_output = r_nodes.new(type='ShaderNodeOutputMaterial')
node_r_principled = r_nodes.new(type='ShaderNodeBsdfPrincipled')
node_r_principled.inputs['Base Color'].default_value = (0.72, 0.28, 0.06, 1.0) # Rocky Orange
node_r_principled.inputs['Roughness'].default_value = 0.98

node_r_noise = r_nodes.new(type='ShaderNodeTexNoise')
node_r_noise.inputs['Scale'].default_value = 18.0
node_r_noise.inputs['Detail'].default_value = 8.0

node_r_bump = r_nodes.new(type='ShaderNodeBump')
node_r_bump.inputs['Strength'].default_value = 0.75

r_links.new(node_r_noise.outputs['Fac'], node_r_bump.inputs['Height'])
r_links.new(node_r_bump.outputs['Normal'], node_r_principled.inputs['Normal'])
r_links.new(node_r_principled.outputs['BSDF'], node_r_output.inputs['Surface'])

displace_tex = bpy.data.textures.new(name="Rock_Displace_Tex", type='CLOUDS')
displace_tex.noise_scale = 0.2

def apply_rock_material(obj):
    """Assigns the basic visual material to the object."""
    if len(obj.data.materials) == 0:
        obj.data.materials.append(rock_mat)
    else:
        obj.data.materials[0] = rock_mat

def apply_rock_modifiers(obj):
    """Applies the actual heavy geometry modifiers (called AFTER animation loop)."""
    subsurf = obj.modifiers.new(name="Rock_Subsurf", type='SUBSURF')
    subsurf.levels = 2
    subsurf.render_levels = 2

    displace = obj.modifiers.new(name="Rock_Displace", type='DISPLACE')
    displace.texture = displace_tex
    displace.strength = 0.085

# Track all parts to add modifiers to them at the very end
monster_parts = []

# ==========================================
# 3. BUILD THE BULKED MONSTER (LOW POLY BASE)
# ==========================================
root_z_height = 1.9

bpy.ops.object.empty_add(type='PLAIN_AXES', location=(6, 0, root_z_height))
root = bpy.context.object
root.name = "Stick_Root"

# Torso
torso = bpy.ops.mesh.primitive_cylinder_add(radius=0.32, depth=1.2, location=(0, 0, 0))
torso = bpy.context.object
torso.name = "Torso"
torso.parent = root
torso.location = (0, 0, 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(torso)
monster_parts.append(torso)

# Head
bpy.ops.mesh.primitive_uv_sphere_add(radius=0.34, location=(0, 0, 0.85))
head = bpy.context.object
head.name = "Head"
head.parent = torso
apply_rock_material(head)
monster_parts.append(head)

# Shoulders
bpy.ops.mesh.primitive_cylinder_add(radius=0.18, depth=0.9, location=(0, 0, 0.5))
shoulders = bpy.context.object
shoulders.name = "Shoulders"
shoulders.parent = torso
shoulders.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(shoulders)
monster_parts.append(shoulders)

# Hips
bpy.ops.mesh.primitive_cylinder_add(radius=0.15, depth=0.6, location=(0, 0, -0.6))
hips = bpy.context.object
hips.name = "Hips"
hips.parent = torso
hips.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(hips)
monster_parts.append(hips)

def create_limb(name, parent, local_position, length=1.0, radius=0.04):
    bpy.ops.mesh.primitive_cylinder_add(radius=radius, depth=length, location=(0, 0, 0))
    limb = bpy.context.object
    limb.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.translate(value=(0, 0, -length / 2))
    bpy.ops.object.mode_set(mode='OBJECT')

    limb.parent = parent
    limb.location = local_position
    apply_rock_material(limb)
    monster_parts.append(limb)
    return limb

def attach_hand(name, parent, local_position):
    bpy.ops.mesh.primitive_uv_sphere_add(radius=0.16, location=(0, 0, 0))
    hand = bpy.context.object
    hand.name = name
    hand.parent = parent
    hand.location = local_position
    apply_rock_material(hand)
    monster_parts.append(hand)
    return hand

def attach_foot(name, parent, local_position):
    bpy.ops.mesh.primitive_cube_add(size=1, location=(0, 0, 0))
    foot = bpy.context.object
    foot.name = name

    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.resize(value=(0.34, 0.44, 0.16))
    bpy.ops.transform.translate(value=(0, 0.16, -0.02))
    bpy.ops.object.mode_set(mode='OBJECT')

    foot.parent = parent
    foot.location = local_position
    apply_rock_material(foot)
    monster_parts.append(foot)
    return foot

# Generate Arms & Legs
upper_arm_l = create_limb("Upper_Arm_L", torso, (-0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_l   = create_limb("Forearm_L", upper_arm_l, (0, 0, -0.45), length=0.45, radius=0.12)
hand_l      = attach_hand("Hand_L", forearm_l, (0, 0, -0.45))

upper_arm_r = create_limb("Upper_Arm_R", torso, (0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_r   = create_limb("Forearm_R", upper_arm_r, (0, 0, -0.45), length=0.45, radius=0.12)
hand_r      = attach_hand("Hand_R", forearm_r, (0, 0, -0.45))

leg_segment_length = 0.65
thigh_l = create_limb("Thigh_L", torso, (-0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_l  = create_limb("Shin_L", thigh_l, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_l  = attach_foot("Foot_L", shin_l, (0, 0, -leg_segment_length))

thigh_r = create_limb("Thigh_R", torso, (0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_r  = create_limb("Shin_R", thigh_r, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_r  = attach_foot("Foot_R", shin_r, (0, 0, -leg_segment_length))

# ==========================================
# 4. PROP SETUP: SCROLL PIECES
# ==========================================
bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_r = bpy.context.object
scroll_roll_r.name = "Scroll_Roll_R"

bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_l = bpy.context.object
scroll_roll_l.name = "Scroll_Roll_L"

bpy.ops.mesh.primitive_plane_add(size=1)
scroll_paper = bpy.context.object
scroll_paper.name = "Scroll_Paper"

bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.transform.rotate(value=math.radians(90), orient_axis='X')
bpy.ops.transform.resize(value=(1.0, 1.0, 0.36))
bpy.ops.object.mode_set(mode='OBJECT')

# Material Setup for Scroll
mat = bpy.data.materials.new(name="Scroll_Texture_Material")
mat.use_nodes = True
nodes = mat.node_tree.nodes
links = mat.node_tree.links
nodes.clear()

node_tex_coord = nodes.new(type='ShaderNodeTexCoord')
node_mapping   = nodes.new(type='ShaderNodeMapping')
node_texture   = nodes.new(type='ShaderNodeTexImage')
node_principled= nodes.new(type='ShaderNodeBsdfPrincipled')
node_output    = nodes.new(type='ShaderNodeOutputMaterial')

node_mapping.vector_type = 'POINT'
node_tex_coord.location  = (-600, 0)
node_mapping.location    = (-400, 0)
node_texture.location    = (-150, 0)
node_principled.location = (150, 0)
node_output.location     = (400, 0)

image_path = "/Users/dobbinp1/Downloads/IMGP6239_psedit.jpg"
if os.path.exists(image_path):
    try:
        img = bpy.data.images.load(image_path)
        node_texture.image = img
    except Exception as e:
        print(f"Image load error: {e}")
else:
    img = bpy.data.images.new("Fallback_Grid", width=1024, height=1024)
    img.generated_type = 'GRID'
    node_texture.image = img

links.new(node_tex_coord.outputs['UV'], node_mapping.inputs['Vector'])
links.new(node_mapping.outputs['Vector'], node_texture.inputs['Vector'])
links.new(node_texture.outputs['Color'], node_principled.inputs['Base Color'])
links.new(node_principled.outputs['BSDF'], node_output.inputs['Surface'])

if len(scroll_paper.data.materials) == 0:
    scroll_paper.data.materials.append(mat)
else:
    scroll_paper.data.materials[0] = mat

# ==========================================
# 5. KINEMATIC TARGET CALCULATIONS
# ==========================================
target_alpha = math.radians(30)
target_gamma = math.radians(30)
eff_length = 0.45 * math.cos(target_alpha) + 0.45 * math.cos(target_alpha + target_gamma)
target_beta_r = math.asin(0.45 / eff_length)
target_beta_l = -target_beta_r

# ==========================================
# 6. ROOT PATH KEYFRAMES
# ==========================================
scene.frame_set(1)
root.location = (6, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(65)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(75)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(180))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

for f in [92, 105, 125, 145, 160]:
    scene.frame_set(f)
    root.location = (0, 0, root_z_height)
    root.rotation_euler = (0, 0, math.radians(180))
    root.keyframe_insert(data_path="location")
    root.keyframe_insert(data_path="rotation_euler")

# ==========================================
# 7. LIGHTWEIGHT ANIMATION LOOP
# ==========================================
# We calculate hands setup using the low poly base structure (Fast!)
scene.frame_set(125)
bpy.context.view_layer.update()
peak_span = (hand_l.matrix_world.to_translation() - hand_r.matrix_world.to_translation()).length

for frame in range(1, 161):
    scene.frame_set(frame)
    unfurl_factor = 0.0

    if frame <= 65:
        if frame < 55: damping = 1.0
        else: damping = 1.0 - ((frame - 55) / 10.0)

        walk_speed = 0.45
        swing = math.sin(frame * walk_speed) * math.radians(26) * damping
        thigh_cos = math.cos(frame * walk_speed)

        thigh_l.rotation_euler = (swing, 0, 0)
        thigh_r.rotation_euler = (-swing, 0, 0)
        shin_l.rotation_euler = (-max(0.0, thigh_cos) * math.radians(50) * damping, 0, 0)
        shin_r.rotation_euler = (-max(0.0, -thigh_cos) * math.radians(50) * damping, 0, 0)
        foot_l.rotation_euler = (-thigh_l.rotation_euler[0] - shin_l.rotation_euler[0], 0, 0)
        foot_r.rotation_euler = (-thigh_r.rotation_euler[0] - shin_r.rotation_euler[0], 0, 0)

        upper_arm_l.rotation_euler = (-swing, 0, 0)
        forearm_l.rotation_euler = (math.radians(20), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 75:
        t = (frame - 65) / 10.0
        for leg in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r]:
            leg.rotation_euler = (0, 0, 0)

        upper_arm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)
        forearm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 92:
        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

        upper_arm_l.rotation_euler = (math.radians(45), math.radians(15), 0)
        beckon_wave = math.sin((frame - 76) * 0.8)
        forearm_l.rotation_euler = (math.radians(60) + beckon_wave * math.radians(25), 0, 0)

    elif frame <= 105:
        t = (frame - 92) / 13.0

        upper_arm_r.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(-10) + t * (target_beta_r - math.radians(-10)),
            0
        )
        forearm_r.rotation_euler = (math.radians(60) + t * (target_gamma - math.radians(60)), 0, 0)

        start_fore_l = math.radians(60) + math.sin((92 - 76) * 0.8) * math.radians(25)
        upper_arm_l.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(15) + t * (target_beta_l - math.radians(15)),
            0
        )
        forearm_l.rotation_euler = (start_fore_l + t * (target_gamma - start_fore_l), 0, 0)

    elif frame <= 125:
        t = (frame - 105) / 20.0
        unfurl_factor = t

        curr_beta_r = target_beta_r + t * (math.radians(-15) - target_beta_r)
        curr_beta_l = target_beta_l + t * (math.radians(15) - target_beta_l)

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    elif frame <= 145:
        unfurl_factor = 1.0

        upper_arm_r.rotation_euler = (target_alpha, math.radians(-15), 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, math.radians(15), 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    else:
        t = (frame - 145) / 15.0
        unfurl_factor = 1.0 - t

        curr_beta_r = math.radians(-15) + t * (target_beta_r - math.radians(-15))
        curr_beta_l = math.radians(15) + t * (target_beta_l - math.radians(15))

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    for limb in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r, upper_arm_l, forearm_l, upper_arm_r, forearm_r]:
        limb.keyframe_insert(data_path="rotation_euler")

    # Update world matrix changes for scroll tracking
    bpy.context.view_layer.update()

    wpos_r = hand_r.matrix_world.to_translation()
    wpos_l = hand_l.matrix_world.to_translation()

    scroll_roll_r.location = wpos_r
    scroll_roll_l.location = wpos_r + unfurl_factor * (wpos_l - wpos_r)

    scroll_paper.location = (scroll_roll_r.location + scroll_roll_l.location) / 2.0
    span = (scroll_roll_l.location - scroll_roll_r.location).length
    scroll_paper.scale = (max(0.01, span), 1.0, 1.0)

    node_mapping.inputs['Scale'].default_value = (peak_span, 1.0, 1.0)
    node_mapping.inputs['Location'].default_value = (-0.5 * peak_span + 0.5, 0.0, 0.0)

    scroll_roll_r.rotation_euler = (0, 0, 0)
    scroll_roll_l.rotation_euler = (0, 0, 0)
    scroll_paper.rotation_euler = (0, 0, 0)

    for prop in [scroll_roll_r, scroll_roll_l, scroll_paper]:
        prop.keyframe_insert(data_path="location")
        prop.keyframe_insert(data_path="rotation_euler")
    scroll_paper.keyframe_insert(data_path="scale")

    node_mapping.inputs['Scale'].keyframe_insert(data_path="default_value")
    node_mapping.inputs['Location'].keyframe_insert(data_path="default_value")

# ==========================================
# 8. POST-LOOP DEFERRED MODIFIER GENERATION
# ==========================================
# Now that animation matrices are baked, we add rock geometry modifiers *once*
for part in monster_parts:
    apply_rock_modifiers(part)

# ==========================================
# 9. CAMERA MOVEMENT TRACKING
# ==========================================
scene.frame_set(1)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(105)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(125)
camera.location = (0, -5.2, 2.0)
camera.keyframe_insert(data_path="location")

scene.frame_set(1)
print("Hyper-optimized script complete! Character rocks are fully rendered.")
# Out:
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/2858500131.py:39: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   rock_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/2858500131.py:225: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   mat.use_nodes = True
# Hyper-optimized script complete! Character rocks are fully rendered.

# %%
import bpy
import math
import mathutils
import os

# ==========================================
# 1. SETUP ENVIRONMENT & CLEAN SCENE
# ==========================================
if bpy.context.object and bpy.context.object.mode != 'OBJECT':
    bpy.ops.object.mode_set(mode='OBJECT')

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete()

scene = bpy.context.scene
scene.frame_start = 1
scene.frame_end = 160
scene.frame_current = 1

scene.render.engine = 'CYCLES'

# Add standard Camera (angled to catch the wide-open horizon and sky)
bpy.ops.object.camera_add(location=(0, -12, 2.5), rotation=(math.radians(84), 0, 0))
camera = bpy.context.object
scene.camera = camera

# Add a Light source
bpy.ops.object.light_add(type='SUN', location=(5, -10, 10))
sun = bpy.context.object
sun.data.energy = 2.5
sun.rotation_euler = (math.radians(45), math.radians(0), math.radians(35))

# ==========================================
# 1b. PROCEDURAL SKY SETUP (UNOBSTRUCTED VIEW)
# ==========================================
world = scene.world
world.use_nodes = True
wnodes = world.node_tree.nodes
wlinks = world.node_tree.links
wnodes.clear()

node_w_output = wnodes.new(type='ShaderNodeOutputWorld')
node_w_background = wnodes.new(type='ShaderNodeBackground')
node_w_sky = wnodes.new(type='ShaderNodeTexSky')

# Late afternoon atmosphere setting
node_w_sky.sky_type = 'MULTIPLE_SCATTERING'
node_w_sky.sun_elevation = math.radians(16)
node_w_sky.sun_rotation = math.radians(130)
node_w_sky.altitude = 50.0
node_w_sky.air_density = 1.0
node_w_sky.aerosol_density = 0.4
node_w_sky.ozone_density = 2.0

wlinks.new(node_w_sky.outputs['Color'], node_w_background.inputs['Color'])
wlinks.new(node_w_background.outputs['Background'], node_w_output.inputs['Surface'])

# ==========================================
# 2. CREATE ENVIRONMENT MATERIALS
# ==========================================
# Green Grass Material
grass_mat = bpy.data.materials.new(name="Grass_Material")
grass_mat.use_nodes = True
g_nodes = grass_mat.node_tree.nodes
g_links = grass_mat.node_tree.links
g_nodes.clear()

node_g_output = g_nodes.new(type='ShaderNodeOutputMaterial')
node_g_principled = g_nodes.new(type='ShaderNodeBsdfPrincipled')
node_g_principled.inputs['Base Color'].default_value = (0.14, 0.38, 0.09, 1.0)
node_g_principled.inputs['Roughness'].default_value = 0.9
node_g_noise = g_nodes.new(type='ShaderNodeTexNoise')
node_g_noise.inputs['Scale'].default_value = 120.0
node_g_bump = g_nodes.new(type='ShaderNodeBump')
node_g_bump.inputs['Strength'].default_value = 0.25
g_links.new(node_g_noise.outputs['Fac'], node_g_bump.inputs['Height'])
g_links.new(node_g_bump.outputs['Normal'], node_g_principled.inputs['Normal'])
g_links.new(node_g_principled.outputs['BSDF'], node_g_output.inputs['Surface'])

# Road Material
road_mat = bpy.data.materials.new(name="Road_Material")
road_mat.use_nodes = True
ro_nodes = road_mat.node_tree.nodes
ro_links = road_mat.node_tree.links
ro_nodes.clear()

node_ro_output = ro_nodes.new(type='ShaderNodeOutputMaterial')
node_ro_principled = ro_nodes.new(type='ShaderNodeBsdfPrincipled')
node_ro_principled.inputs['Base Color'].default_value = (0.42, 0.34, 0.26, 1.0)
node_ro_principled.inputs['Roughness'].default_value = 0.99
node_ro_noise = ro_nodes.new(type='ShaderNodeTexNoise')
node_ro_noise.inputs['Scale'].default_value = 40.0
node_ro_bump = ro_nodes.new(type='ShaderNodeBump')
node_ro_bump.inputs['Strength'].default_value = 0.3
ro_links.new(node_ro_noise.outputs['Fac'], node_ro_bump.inputs['Height'])
ro_links.new(node_ro_bump.outputs['Normal'], node_ro_principled.inputs['Normal'])
ro_links.new(node_ro_principled.outputs['BSDF'], node_ro_output.inputs['Surface'])

# Weathered Boulder Material
boulder_mat = bpy.data.materials.new(name="Boulder_Material")
boulder_mat.use_nodes = True
b_nodes = boulder_mat.node_tree.nodes
b_links = boulder_mat.node_tree.links
b_nodes.clear()

node_b_output = b_nodes.new(type='ShaderNodeOutputMaterial')
node_b_principled = b_nodes.new(type='ShaderNodeBsdfPrincipled')
node_b_principled.inputs['Base Color'].default_value = (0.28, 0.28, 0.28, 1.0)
node_b_principled.inputs['Roughness'].default_value = 0.95
node_b_noise = b_nodes.new(type='ShaderNodeTexNoise')
node_b_noise.inputs['Scale'].default_value = 12.0
node_b_noise.inputs['Detail'].default_value = 8.0
node_b_bump = b_nodes.new(type='ShaderNodeBump')
node_b_bump.inputs['Strength'].default_value = 0.7
b_links.new(node_b_noise.outputs['Fac'], node_b_bump.inputs['Height'])
b_links.new(node_b_bump.outputs['Normal'], node_b_principled.inputs['Normal'])
b_links.new(node_b_principled.outputs['BSDF'], node_b_output.inputs['Surface'])

displace_tex = bpy.data.textures.new(name="Rock_Displace_Tex", type='CLOUDS')
displace_tex.noise_scale = 0.2

boulder_displace_tex = bpy.data.textures.new(name="Boulder_Displace_Tex", type='VORONOI')
boulder_displace_tex.noise_scale = 0.6

# ==========================================
# 2b. GENERATE ENVIRONMENT GEOMETRY
# ==========================================
# Vast Grass Terrain extending fully to the horizon
bpy.ops.mesh.primitive_plane_add(size=1000, location=(0, 0, 0))
ground = bpy.context.object
ground.name = "Grass_Terrain"
ground.data.materials.append(grass_mat)

# The Dirt Road (Extended to match the horizon scale)
bpy.ops.mesh.primitive_plane_add(size=1, location=(0, 0, 0.002))
road = bpy.context.object
road.name = "Dirt_Road"
road.scale = (1000, 3.5, 1)
road.data.materials.append(road_mat)

# Boulders repositioned inward to sit roughly 50% within the camera viewport boundaries
boulder_configs = [
    (-9.5, 15, 1.0, (4.5, 3.5, 3.8)),   # Left Border Midground
    (-14.0, 28, 2.5, (7.5, 6.0, 7.0)),  # Left Border Background
    (9.5, 14, 1.0, (4.0, 4.0, 3.5)),    # Right Border Midground
    (14.0, 25, 2.0, (6.0, 5.5, 5.5))    # Right Border Background
]
boulders = []

for i, (x, y, z, scale_xyz) in enumerate(boulder_configs):
    bpy.ops.mesh.primitive_ico_sphere_add(subdivisions=3, radius=1.0, location=(x, y, z))
    boulder = bpy.context.object
    boulder.name = f"Peripheral_Boulder_{i}"
    boulder.scale = scale_xyz
    boulder.data.materials.append(boulder_mat)
    boulders.append(boulder)

# ==========================================
# 3. ROCK LOOK GENERATOR (MONSTER MATERIAL)
# ==========================================
rock_mat = bpy.data.materials.new(name="Rock_Material")
rock_mat.use_nodes = True
r_nodes = rock_mat.node_tree.nodes
r_links = rock_mat.node_tree.links
r_nodes.clear()

node_r_output = r_nodes.new(type='ShaderNodeOutputMaterial')
node_r_principled = r_nodes.new(type='ShaderNodeBsdfPrincipled')
node_r_principled.inputs['Base Color'].default_value = (0.72, 0.28, 0.06, 1.0)
node_r_principled.inputs['Roughness'].default_value = 0.98

node_r_noise = r_nodes.new(type='ShaderNodeTexNoise')
node_r_noise.inputs['Scale'].default_value = 18.0
node_r_noise.inputs['Detail'].default_value = 8.0

node_r_bump = r_nodes.new(type='ShaderNodeBump')
node_r_bump.inputs['Strength'].default_value = 0.75

r_links.new(node_r_noise.outputs['Fac'], node_r_bump.inputs['Height'])
r_links.new(node_r_bump.outputs['Normal'], node_r_principled.inputs['Normal'])
r_links.new(node_r_principled.outputs['BSDF'], node_r_output.inputs['Surface'])

def apply_rock_material(obj):
    if len(obj.data.materials) == 0:
        obj.data.materials.append(rock_mat)
    else:
        obj.data.materials[0] = rock_mat

monster_parts = []

# ==========================================
# 4. BUILD THE BULKED MONSTER
# ==========================================
root_z_height = 1.9

bpy.ops.object.empty_add(type='PLAIN_AXES', location=(6, 0, root_z_height))
root = bpy.context.object
root.name = "Stick_Root"

# Torso
torso = bpy.ops.mesh.primitive_cylinder_add(radius=0.32, depth=1.2, location=(0, 0, 0))
torso = bpy.context.object
torso.name = "Torso"
torso.parent = root
torso.location = (0, 0, 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(torso)
monster_parts.append(torso)

# Head
bpy.ops.mesh.primitive_uv_sphere_add(radius=0.34, location=(0, 0, 0.85))
head = bpy.context.object
head.name = "Head"
head.parent = torso
apply_rock_material(head)
monster_parts.append(head)

# Shoulders
bpy.ops.mesh.primitive_cylinder_add(radius=0.18, depth=0.9, location=(0, 0, 0.5))
shoulders = bpy.context.object
shoulders.name = "Shoulders"
shoulders.parent = torso
shoulders.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(shoulders)
monster_parts.append(shoulders)

# Hips
bpy.ops.mesh.primitive_cylinder_add(radius=0.15, depth=0.6, location=(0, 0, -0.6))
hips = bpy.context.object
hips.name = "Hips"
hips.parent = torso
hips.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(hips)
monster_parts.append(hips)

def create_limb(name, parent, local_position, length=1.0, radius=0.04):
    bpy.ops.mesh.primitive_cylinder_add(radius=radius, depth=length, location=(0, 0, 0))
    limb = bpy.context.object
    limb.name = name
    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.translate(value=(0, 0, -length / 2))
    bpy.ops.object.mode_set(mode='OBJECT')
    limb.parent = parent
    limb.location = local_position
    apply_rock_material(limb)
    monster_parts.append(limb)
    return limb

def attach_hand(name, parent, local_position):
    bpy.ops.mesh.primitive_uv_sphere_add(radius=0.16, location=(0, 0, 0))
    hand = bpy.context.object
    hand.name = name
    hand.parent = parent
    hand.location = local_position
    apply_rock_material(hand)
    monster_parts.append(hand)
    return hand

def attach_foot(name, parent, local_position):
    bpy.ops.mesh.primitive_cube_add(size=1, location=(0, 0, 0))
    foot = bpy.context.object
    foot.name = name
    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.resize(value=(0.34, 0.44, 0.16))
    bpy.ops.transform.translate(value=(0, 0.16, -0.02))
    bpy.ops.object.mode_set(mode='OBJECT')
    foot.parent = parent
    foot.location = local_position
    apply_rock_material(foot)
    monster_parts.append(foot)
    return foot

upper_arm_l = create_limb("Upper_Arm_L", torso, (-0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_l   = create_limb("Forearm_L", upper_arm_l, (0, 0, -0.45), length=0.45, radius=0.12)
hand_l      = attach_hand("Hand_L", forearm_l, (0, 0, -0.45))

upper_arm_r = create_limb("Upper_Arm_R", torso, (0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_r   = create_limb("Forearm_R", upper_arm_r, (0, 0, -0.45), length=0.45, radius=0.12)
hand_r      = attach_hand("Hand_R", forearm_r, (0, 0, -0.45))

leg_segment_length = 0.65
thigh_l = create_limb("Thigh_L", torso, (-0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_l  = create_limb("Shin_L", thigh_l, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_l  = attach_foot("Foot_L", shin_l, (0, 0, -leg_segment_length))

thigh_r = create_limb("Thigh_R", torso, (0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_r  = create_limb("Shin_R", thigh_r, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_r  = attach_foot("Foot_R", shin_r, (0, 0, -leg_segment_length))

# ==========================================
# 5. PROP SETUP: SCROLL PIECES
# ==========================================
bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_r = bpy.context.object
scroll_roll_r.name = "Scroll_Roll_R"

bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_l = bpy.context.object
scroll_roll_l.name = "Scroll_Roll_L"

bpy.ops.mesh.primitive_plane_add(size=1)
scroll_paper = bpy.context.object
scroll_paper.name = "Scroll_Paper"

bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.transform.rotate(value=math.radians(90), orient_axis='X')
bpy.ops.transform.resize(value=(1.0, 1.0, 0.36))
bpy.ops.object.mode_set(mode='OBJECT')

mat = bpy.data.materials.new(name="Scroll_Texture_Material")
mat.use_nodes = True
nodes = mat.node_tree.nodes
links = mat.node_tree.links
nodes.clear()

node_tex_coord = nodes.new(type='ShaderNodeTexCoord')
node_mapping   = nodes.new(type='ShaderNodeMapping')
node_texture   = nodes.new(type='ShaderNodeTexImage')
node_principled= nodes.new(type='ShaderNodeBsdfPrincipled')
node_output    = nodes.new(type='ShaderNodeOutputMaterial')

node_mapping.vector_type = 'POINT'
node_texture.interpolation = 'Smart'

image_path = "/Users/dobbinp1/Downloads/IMGP6239_psedit.jpg"
if os.path.exists(image_path):
    try:
        img = bpy.data.images.load(image_path)
        node_texture.image = img
    except Exception as e:
        print(f"Image load error: {e}")
else:
    img = bpy.data.images.new("Fallback_Grid", width=1024, height=1024)
    img.generated_type = 'GRID'
    node_texture.image = img

links.new(node_tex_coord.outputs['UV'], node_mapping.inputs['Vector'])
links.new(node_mapping.outputs['Vector'], node_texture.inputs['Vector'])
links.new(node_texture.outputs['Color'], node_principled.inputs['Base Color'])
links.new(node_principled.outputs['BSDF'], node_output.inputs['Surface'])

scroll_paper.data.materials.append(mat)

# ==========================================
# 6. KINEMATIC TARGET CALCULATIONS
# ==========================================
target_alpha = math.radians(30)
target_gamma = math.radians(30)
eff_length = 0.45 * math.cos(target_alpha) + 0.45 * math.cos(target_alpha + target_gamma)
target_beta_r = math.asin(0.45 / eff_length)
target_beta_l = -target_beta_r

# ==========================================
# 7. ROOT PATH KEYFRAMES
# ==========================================
scene.frame_set(1)
root.location = (6, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(65)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(75)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(180))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

for f in [92, 105, 125, 145, 160]:
    scene.frame_set(f)
    root.location = (0, 0, root_z_height)
    root.rotation_euler = (0, 0, math.radians(180))
    root.keyframe_insert(data_path="location")
    root.keyframe_insert(data_path="rotation_euler")

# ==========================================
# 8. LIGHTWEIGHT ANIMATION LOOP
# ==========================================
scene.frame_set(125)
bpy.context.view_layer.update()
peak_span = (hand_l.matrix_world.to_translation() - hand_r.matrix_world.to_translation()).length

for frame in range(1, 161):
    scene.frame_set(frame)
    unfurl_factor = 0.0

    if frame <= 65:
        if frame < 55: damping = 1.0
        else: damping = 1.0 - ((frame - 55) / 10.0)

        walk_speed = 0.45
        swing = math.sin(frame * walk_speed) * math.radians(26) * damping
        thigh_cos = math.cos(frame * walk_speed)

        thigh_l.rotation_euler = (swing, 0, 0)
        thigh_r.rotation_euler = (-swing, 0, 0)
        shin_l.rotation_euler = (-max(0.0, thigh_cos) * math.radians(50) * damping, 0, 0)
        shin_r.rotation_euler = (-max(0.0, -thigh_cos) * math.radians(50) * damping, 0, 0)
        foot_l.rotation_euler = (-thigh_l.rotation_euler[0] - shin_l.rotation_euler[0], 0, 0)
        foot_r.rotation_euler = (-thigh_r.rotation_euler[0] - shin_r.rotation_euler[0], 0, 0)

        upper_arm_l.rotation_euler = (-swing, 0, 0)
        forearm_l.rotation_euler = (math.radians(20), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 75:
        t = (frame - 65) / 10.0
        for leg in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r]:
            leg.rotation_euler = (0, 0, 0)

        upper_arm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)
        forearm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 92:
        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

        upper_arm_l.rotation_euler = (math.radians(45), math.radians(15), 0)
        beckon_wave = math.sin((frame - 76) * 0.8)
        forearm_l.rotation_euler = (math.radians(60) + beckon_wave * math.radians(25), 0, 0)

    elif frame <= 105:
        t = (frame - 92) / 13.0

        upper_arm_r.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(-10) + t * (target_beta_r - math.radians(-10)),
            0
        )
        forearm_r.rotation_euler = (math.radians(60) + t * (target_gamma - math.radians(60)), 0, 0)

        start_fore_l = math.radians(60) + math.sin((92 - 76) * 0.8) * math.radians(25)
        upper_arm_l.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(15) + t * (target_beta_l - math.radians(15)),
            0
        )
        forearm_l.rotation_euler = (start_fore_l + t * (target_gamma - start_fore_l), 0, 0)

    elif frame <= 125:
        t = (frame - 105) / 20.0
        unfurl_factor = t

        curr_beta_r = target_beta_r + t * (math.radians(-15) - target_beta_r)
        curr_beta_l = target_beta_l + t * (math.radians(15) - target_beta_l)

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    elif frame <= 145:
        unfurl_factor = 1.0

        upper_arm_r.rotation_euler = (target_alpha, math.radians(-15), 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, math.radians(15), 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    else:
        t = (frame - 145) / 15.0
        unfurl_factor = 1.0 - t

        curr_beta_r = math.radians(-15) + t * (target_beta_r - math.radians(-15))
        curr_beta_l = math.radians(15) + t * (target_beta_l - math.radians(15))

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    for limb in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r, upper_arm_l, forearm_l, upper_arm_r, forearm_r]:
        limb.keyframe_insert(data_path="rotation_euler")

    bpy.context.view_layer.update()

    wpos_r = hand_r.matrix_world.to_translation()
    wpos_l = hand_l.matrix_world.to_translation()

    scroll_roll_r.location = wpos_r
    scroll_roll_l.location = wpos_r + unfurl_factor * (wpos_l - wpos_r)

    scroll_paper.location = (scroll_roll_r.location + scroll_roll_l.location) / 2.0
    span = (scroll_roll_l.location - scroll_roll_r.location).length
    scroll_paper.scale = (max(0.01, span), 1.0, 1.0)

    node_mapping.inputs['Scale'].default_value = (peak_span, 1.0, 1.0)
    node_mapping.inputs['Location'].default_value = (-0.5 * peak_span + 0.5, 0.0, 0.0)

    scroll_roll_r.rotation_euler = (0, 0, 0)
    scroll_roll_l.rotation_euler = (0, 0, 0)
    scroll_paper.rotation_euler = (0, 0, 0)

    for prop in [scroll_roll_r, scroll_roll_l, scroll_paper]:
        prop.keyframe_insert(data_path="location")
        prop.keyframe_insert(data_path="rotation_euler")
    scroll_paper.keyframe_insert(data_path="scale")

    node_mapping.inputs['Scale'].keyframe_insert(data_path="default_value")
    node_mapping.inputs['Location'].keyframe_insert(data_path="default_value")

# ==========================================
# 9. DEFERRED GEOMETRY DECORATION (FAST)
# ==========================================
# Bake procedural displacement onto monster parts
for part in monster_parts:
    subsurf = part.modifiers.new(name="Rock_Subsurf", type='SUBSURF')
    subsurf.levels = 2
    subsurf.render_levels = 2
    displace = part.modifiers.new(name="Rock_Displace", type='DISPLACE')
    displace.texture = displace_tex
    displace.strength = 0.085

# Bake texture onto the framing peripheral boulders
for b in boulders:
    subsurf = b.modifiers.new(name="Boulder_Subsurf", type='SUBSURF')
    subsurf.levels = 1
    subsurf.render_levels = 2
    displace = b.modifiers.new(name="Boulder_Displace", type='DISPLACE')
    displace.texture = boulder_displace_tex
    displace.strength = 0.35
    displace.direction = 'NORMAL'

# ==========================================
# 10. CAMERA MOVEMENT TRACKING
# ==========================================
scene.frame_set(1)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(105)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(125)
camera.location = (0, -5.2, 2.0)
camera.keyframe_insert(data_path="location")

scene.frame_set(1)
print("Layout adjusted! The boulders are now half-visible on the viewport borders.")
# Out:
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:37: DeprecationWarning: 'World.use_nodes' is expected to be removed in Blender 6.0
#   world.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:63: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   grass_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:82: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   road_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:101: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   boulder_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:162: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   rock_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/3606289988.py:327: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   mat.use_nodes = True
# Layout adjusted! The boulders are now half-visible on the viewport borders.

# %%
import bpy
import math
import mathutils
import os

# ==========================================
# 1. SETUP ENVIRONMENT & CLEAN SCENE
# ==========================================
if bpy.context.object and bpy.context.object.mode != 'OBJECT':
    bpy.ops.object.mode_set(mode='OBJECT')

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete()

scene = bpy.context.scene
scene.frame_start = 1
scene.frame_end = 160
scene.frame_current = 1

scene.render.engine = 'CYCLES'

# Add standard Camera (angled to catch the wide-open horizon and sky)
bpy.ops.object.camera_add(location=(0, -12, 2.5), rotation=(math.radians(84), 0, 0))
camera = bpy.context.object
scene.camera = camera

# Add a Light source
bpy.ops.object.light_add(type='SUN', location=(5, -10, 10))
sun = bpy.context.object
sun.data.energy = 2.5
sun.rotation_euler = (math.radians(45), math.radians(0), math.radians(35))

# ==========================================
# 1b. PROCEDURAL SKY SETUP (UNOBSTRUCTED VIEW)
# ==========================================
world = scene.world
world.use_nodes = True
wnodes = world.node_tree.nodes
wlinks = world.node_tree.links
wnodes.clear()

node_w_output = wnodes.new(type='ShaderNodeOutputWorld')
node_w_background = wnodes.new(type='ShaderNodeBackground')
node_w_sky = wnodes.new(type='ShaderNodeTexSky')

# Late afternoon atmosphere setting
node_w_sky.sky_type = 'MULTIPLE_SCATTERING'
node_w_sky.sun_elevation = math.radians(16)
node_w_sky.sun_rotation = math.radians(130)
node_w_sky.altitude = 50.0
node_w_sky.air_density = 1.0
node_w_sky.aerosol_density = 0.4
node_w_sky.ozone_density = 2.0

wlinks.new(node_w_sky.outputs['Color'], node_w_background.inputs['Color'])
wlinks.new(node_w_background.outputs['Background'], node_w_output.inputs['Surface'])

# ==========================================
# 2b. GENERATE ENVIRONMENT GEOMETRY & GEONODES
# ==========================================
# 1. Master Grass Blade Object (Placed far below the map grid out of sight)
bpy.ops.mesh.primitive_cone_add(vertices=3, radius1=0.02, depth=0.35, location=(0, 0, -50))
blade = bpy.context.object
blade.name = "Grass_Blade_Asset"
blade.data.materials.append(grass_mat)

# Adjust origin to base of the blade so it scatters correctly on surfaces
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.transform.translate(value=(0, 0, 0.175))
bpy.ops.object.mode_set(mode='OBJECT')
bpy.context.scene.cursor.location = (0, 0, -50)
bpy.ops.object.origin_set(type='ORIGIN_CURSOR')
# Note: We leave hide_viewport and hide_render alone so the instances remain visible!

# 2. Vast Background Grass Terrain (keeps far horizon simple for performance)
bpy.ops.mesh.primitive_plane_add(size=1000, location=(0, 0, -0.01))
ground = bpy.context.object
ground.name = "Grass_Terrain_Backdrop"
ground.data.materials.append(grass_mat)

# 3. Dedicated Foreground Meadow Plane (Where the 3D grass nodes live)
bpy.ops.mesh.primitive_plane_add(size=1, location=(0, 12, 0))
meadow = bpy.context.object
meadow.name = "Grass_Foreground_Meadow"
meadow.scale = (45, 55, 1)

# CRITICAL FIX 1: Apply the scale transform so the mesh updates to its true 45x55 size
bpy.ops.object.transform_apply(scale=True, rotation=False, location=False)
meadow.data.materials.append(grass_mat)

# 4. The Dirt Road
bpy.ops.mesh.primitive_plane_add(size=1, location=(0, 0, 0.002))
road = bpy.context.object
road.name = "Dirt_Road"
road.scale = (1000, 3.5, 1)
road.data.materials.append(road_mat)

# 5. Build the Geometry Nodes Scattering Tree
geo_modifier = meadow.modifiers.new(name="Grass_Scatter_System", type='NODES')
gn_tree = bpy.data.node_groups.new(name="Grass_Scatter_Tree", type='GeometryNodeTree')
geo_modifier.node_group = gn_tree

gn_nodes = gn_tree.nodes
gn_links = gn_tree.links

# Define public modifier interface sockets (Blender 4.0+)
gn_tree.interface.new_socket(name="Geometry", in_out='INPUT', socket_type='NodeSocketGeometry')
gn_tree.interface.new_socket(name="Geometry", in_out='OUTPUT', socket_type='NodeSocketGeometry')

group_input = gn_nodes.new('NodeGroupInput')
group_output = gn_nodes.new('NodeGroupOutput')
group_input.location = (-400, 0)
group_output.location = (800, 0)

distribute = gn_nodes.new(type="GeometryNodeDistributePointsOnFaces")
distribute.inputs['Density'].default_value = 65.0  # Now scatters beautifully across the whole area!

instance = gn_nodes.new(type="GeometryNodeInstanceOnPoints")

obj_info = gn_nodes.new(type="GeometryNodeObjectInfo")
obj_info.inputs['Object'].default_value = blade

# Randomize the scale of blades so they aren't completely uniform
rand_scale = gn_nodes.new(type="FunctionNodeRandomValue")
rand_scale.data_type = 'FLOAT'
rand_scale.inputs['Min'].default_value = 0.6
rand_scale.inputs['Max'].default_value = 1.4

# Randomize rotation (full spin on Z, slight natural leaning variation on X and Y)
rand_rot = gn_nodes.new(type="FunctionNodeRandomValue")
rand_rot.data_type = 'FLOAT_VECTOR'
rand_rot.inputs['Min'].default_value = (-0.15, -0.15, 0.0)
rand_rot.inputs['Max'].default_value = (0.15, 0.15, 6.28)

# CRITICAL FIX 2: Add an explicit Set Material node to ensure instances render properly
set_mat = gn_nodes.new(type="GeometryNodeSetMaterial")
set_mat.inputs['Material'].default_value = grass_mat

join = gn_nodes.new(type="GeometryNodeJoinGeometry")

# Connect the nodes
gn_links.new(group_input.outputs['Geometry'], distribute.inputs['Mesh'])
gn_links.new(distribute.outputs['Points'], instance.inputs['Points'])
gn_links.new(obj_info.outputs['Geometry'], instance.inputs['Instance'])
gn_links.new(rand_scale.outputs['Value'], instance.inputs['Scale'])
gn_links.new(rand_rot.outputs['Value'], instance.inputs['Rotation'])

# Route instances through the material assignment node
gn_links.new(instance.outputs['Instances'], set_mat.inputs['Geometry'])

# Combine the background ground surface with the new grass geometry
gn_links.new(group_input.outputs['Geometry'], join.inputs['Geometry'])
gn_links.new(set_mat.outputs['Geometry'], join.inputs['Geometry'])
gn_links.new(join.outputs['Geometry'], group_output.inputs['Geometry'])

# Boulders repositioned inward to sit roughly 50% within the camera viewport boundaries
boulder_configs = [
    (-9.5, 15, 1.0, (4.5, 3.5, 3.8)),   # Left Border Midground
    (-14.0, 28, 2.5, (7.5, 6.0, 7.0)),  # Left Border Background
    (9.5, 14, 1.0, (4.0, 4.0, 3.5)),    # Right Border Midground
    (14.0, 25, 2.0, (6.0, 5.5, 5.5))    # Right Border Background
]
boulders = []

for i, (x, y, z, scale_xyz) in enumerate(boulder_configs):
    bpy.ops.mesh.primitive_ico_sphere_add(subdivisions=3, radius=1.0, location=(x, y, z))
    boulder = bpy.context.object
    boulder.name = f"Peripheral_Boulder_{i}"
    boulder.scale = scale_xyz
    boulder.data.materials.append(boulder_mat)
    boulders.append(boulder)

# ==========================================
# 3. ROCK LOOK GENERATOR (MONSTER MATERIAL)
# ==========================================
rock_mat = bpy.data.materials.new(name="Rock_Material")
rock_mat.use_nodes = True
r_nodes = rock_mat.node_tree.nodes
r_links = rock_mat.node_tree.links
r_nodes.clear()

node_r_output = r_nodes.new(type='ShaderNodeOutputMaterial')
node_r_principled = r_nodes.new(type='ShaderNodeBsdfPrincipled')
node_r_principled.inputs['Base Color'].default_value = (0.72, 0.28, 0.06, 1.0)
node_r_principled.inputs['Roughness'].default_value = 0.98

node_r_noise = r_nodes.new(type='ShaderNodeTexNoise')
node_r_noise.inputs['Scale'].default_value = 18.0
node_r_noise.inputs['Detail'].default_value = 8.0

node_r_bump = r_nodes.new(type='ShaderNodeBump')
node_r_bump.inputs['Strength'].default_value = 0.75

r_links.new(node_r_noise.outputs['Fac'], node_r_bump.inputs['Height'])
r_links.new(node_r_bump.outputs['Normal'], node_r_principled.inputs['Normal'])
r_links.new(node_r_principled.outputs['BSDF'], node_r_output.inputs['Surface'])

def apply_rock_material(obj):
    if len(obj.data.materials) == 0:
        obj.data.materials.append(rock_mat)
    else:
        obj.data.materials[0] = rock_mat

monster_parts = []

# ==========================================
# 4. BUILD THE BULKED MONSTER
# ==========================================
root_z_height = 1.9

bpy.ops.object.empty_add(type='PLAIN_AXES', location=(6, 0, root_z_height))
root = bpy.context.object
root.name = "Stick_Root"

# Torso
torso = bpy.ops.mesh.primitive_cylinder_add(radius=0.32, depth=1.2, location=(0, 0, 0))
torso = bpy.context.object
torso.name = "Torso"
torso.parent = root
torso.location = (0, 0, 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(torso)
monster_parts.append(torso)

# Head
bpy.ops.mesh.primitive_uv_sphere_add(radius=0.34, location=(0, 0, 0.85))
head = bpy.context.object
head.name = "Head"
head.parent = torso
apply_rock_material(head)
monster_parts.append(head)

# Shoulders
bpy.ops.mesh.primitive_cylinder_add(radius=0.18, depth=0.9, location=(0, 0, 0.5))
shoulders = bpy.context.object
shoulders.name = "Shoulders"
shoulders.parent = torso
shoulders.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(shoulders)
monster_parts.append(shoulders)

# Hips
bpy.ops.mesh.primitive_cylinder_add(radius=0.15, depth=0.6, location=(0, 0, -0.6))
hips = bpy.context.object
hips.name = "Hips"
hips.parent = torso
hips.rotation_euler = (0, math.radians(90), 0)
bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.mesh.subdivide(number_cuts=3)
bpy.ops.object.mode_set(mode='OBJECT')
apply_rock_material(hips)
monster_parts.append(hips)

def create_limb(name, parent, local_position, length=1.0, radius=0.04):
    bpy.ops.mesh.primitive_cylinder_add(radius=radius, depth=length, location=(0, 0, 0))
    limb = bpy.context.object
    limb.name = name
    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.translate(value=(0, 0, -length / 2))
    bpy.ops.object.mode_set(mode='OBJECT')
    limb.parent = parent
    limb.location = local_position
    apply_rock_material(limb)
    monster_parts.append(limb)
    return limb

def attach_hand(name, parent, local_position):
    bpy.ops.mesh.primitive_uv_sphere_add(radius=0.16, location=(0, 0, 0))
    hand = bpy.context.object
    hand.name = name
    hand.parent = parent
    hand.location = local_position
    apply_rock_material(hand)
    monster_parts.append(hand)
    return hand

def attach_foot(name, parent, local_position):
    bpy.ops.mesh.primitive_cube_add(size=1, location=(0, 0, 0))
    foot = bpy.context.object
    foot.name = name
    bpy.ops.object.mode_set(mode='EDIT')
    bpy.ops.mesh.select_all(action='SELECT')
    bpy.ops.mesh.subdivide(number_cuts=3)
    bpy.ops.transform.resize(value=(0.34, 0.44, 0.16))
    bpy.ops.transform.translate(value=(0, 0.16, -0.02))
    bpy.ops.object.mode_set(mode='OBJECT')
    foot.parent = parent
    foot.location = local_position
    apply_rock_material(foot)
    monster_parts.append(foot)
    return foot

upper_arm_l = create_limb("Upper_Arm_L", torso, (-0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_l   = create_limb("Forearm_L", upper_arm_l, (0, 0, -0.45), length=0.45, radius=0.12)
hand_l      = attach_hand("Hand_L", forearm_l, (0, 0, -0.45))

upper_arm_r = create_limb("Upper_Arm_R", torso, (0.45, 0, 0.5), length=0.45, radius=0.14)
forearm_r   = create_limb("Forearm_R", upper_arm_r, (0, 0, -0.45), length=0.45, radius=0.12)
hand_r      = attach_hand("Hand_R", forearm_r, (0, 0, -0.45))

leg_segment_length = 0.65
thigh_l = create_limb("Thigh_L", torso, (-0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_l  = create_limb("Shin_L", thigh_l, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_l  = attach_foot("Foot_L", shin_l, (0, 0, -leg_segment_length))

thigh_r = create_limb("Thigh_R", torso, (0.3, 0, -0.6), length=leg_segment_length, radius=0.16)
shin_r  = create_limb("Shin_R", thigh_r, (0, 0, -leg_segment_length), length=leg_segment_length, radius=0.13)
foot_r  = attach_foot("Foot_R", shin_r, (0, 0, -leg_segment_length))

# ==========================================
# 5. PROP SETUP: SCROLL PIECES
# ==========================================
bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_r = bpy.context.object
scroll_roll_r.name = "Scroll_Roll_R"

bpy.ops.mesh.primitive_cylinder_add(radius=0.025, depth=0.45)
scroll_roll_l = bpy.context.object
scroll_roll_l.name = "Scroll_Roll_L"

bpy.ops.mesh.primitive_plane_add(size=1)
scroll_paper = bpy.context.object
scroll_paper.name = "Scroll_Paper"

bpy.ops.object.mode_set(mode='EDIT')
bpy.ops.mesh.select_all(action='SELECT')
bpy.ops.transform.rotate(value=math.radians(90), orient_axis='X')
bpy.ops.transform.resize(value=(1.0, 1.0, 0.36))
bpy.ops.object.mode_set(mode='OBJECT')

mat = bpy.data.materials.new(name="Scroll_Texture_Material")
mat.use_nodes = True
nodes = mat.node_tree.nodes
links = mat.node_tree.links
nodes.clear()

node_tex_coord = nodes.new(type='ShaderNodeTexCoord')
node_mapping   = nodes.new(type='ShaderNodeMapping')
node_texture   = nodes.new(type='ShaderNodeTexImage')
node_principled= nodes.new(type='ShaderNodeBsdfPrincipled')
node_output    = nodes.new(type='ShaderNodeOutputMaterial')

node_mapping.vector_type = 'POINT'
node_texture.interpolation = 'Smart'

image_path = "/Users/dobbinp1/Downloads/IMGP6239_psedit.jpg"
if os.path.exists(image_path):
    try:
        img = bpy.data.images.load(image_path)
        node_texture.image = img
    except Exception as e:
        print(f"Image load error: {e}")
else:
    img = bpy.data.images.new("Fallback_Grid", width=1024, height=1024)
    img.generated_type = 'GRID'
    node_texture.image = img

links.new(node_tex_coord.outputs['UV'], node_mapping.inputs['Vector'])
links.new(node_mapping.outputs['Vector'], node_texture.inputs['Vector'])
links.new(node_texture.outputs['Color'], node_principled.inputs['Base Color'])
links.new(node_principled.outputs['BSDF'], node_output.inputs['Surface'])

scroll_paper.data.materials.append(mat)

# ==========================================
# 6. KINEMATIC TARGET CALCULATIONS
# ==========================================
target_alpha = math.radians(30)
target_gamma = math.radians(30)
eff_length = 0.45 * math.cos(target_alpha) + 0.45 * math.cos(target_alpha + target_gamma)
target_beta_r = math.asin(0.45 / eff_length)
target_beta_l = -target_beta_r

# ==========================================
# 7. ROOT PATH KEYFRAMES
# ==========================================
scene.frame_set(1)
root.location = (6, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(65)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(90))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

scene.frame_set(75)
root.location = (0, 0, root_z_height)
root.rotation_euler = (0, 0, math.radians(180))
root.keyframe_insert(data_path="location")
root.keyframe_insert(data_path="rotation_euler")

for f in [92, 105, 125, 145, 160]:
    scene.frame_set(f)
    root.location = (0, 0, root_z_height)
    root.rotation_euler = (0, 0, math.radians(180))
    root.keyframe_insert(data_path="location")
    root.keyframe_insert(data_path="rotation_euler")

# ==========================================
# 8. LIGHTWEIGHT ANIMATION LOOP
# ==========================================
scene.frame_set(125)
bpy.context.view_layer.update()
peak_span = (hand_l.matrix_world.to_translation() - hand_r.matrix_world.to_translation()).length

for frame in range(1, 161):
    scene.frame_set(frame)
    unfurl_factor = 0.0

    if frame <= 65:
        if frame < 55: damping = 1.0
        else: damping = 1.0 - ((frame - 55) / 10.0)

        walk_speed = 0.45
        swing = math.sin(frame * walk_speed) * math.radians(26) * damping
        thigh_cos = math.cos(frame * walk_speed)

        thigh_l.rotation_euler = (swing, 0, 0)
        thigh_r.rotation_euler = (-swing, 0, 0)
        shin_l.rotation_euler = (-max(0.0, thigh_cos) * math.radians(50) * damping, 0, 0)
        shin_r.rotation_euler = (-max(0.0, -thigh_cos) * math.radians(50) * damping, 0, 0)
        foot_l.rotation_euler = (-thigh_l.rotation_euler[0] - shin_l.rotation_euler[0], 0, 0)
        foot_r.rotation_euler = (-thigh_r.rotation_euler[0] - shin_r.rotation_euler[0], 0, 0)

        upper_arm_l.rotation_euler = (-swing, 0, 0)
        forearm_l.rotation_euler = (math.radians(20), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 75:
        t = (frame - 65) / 10.0
        for leg in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r]:
            leg.rotation_euler = (0, 0, 0)

        upper_arm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)
        forearm_l.rotation_euler = (math.radians(20) * (1 - t), 0, 0)

        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

    elif frame <= 92:
        upper_arm_r.rotation_euler = (math.radians(45), math.radians(-10), 0)
        forearm_r.rotation_euler = (math.radians(60), 0, 0)

        upper_arm_l.rotation_euler = (math.radians(45), math.radians(15), 0)
        beckon_wave = math.sin((frame - 76) * 0.8)
        forearm_l.rotation_euler = (math.radians(60) + beckon_wave * math.radians(25), 0, 0)

    elif frame <= 105:
        t = (frame - 92) / 13.0

        upper_arm_r.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(-10) + t * (target_beta_r - math.radians(-10)),
            0
        )
        forearm_r.rotation_euler = (math.radians(60) + t * (target_gamma - math.radians(60)), 0, 0)

        start_fore_l = math.radians(60) + math.sin((92 - 76) * 0.8) * math.radians(25)
        upper_arm_l.rotation_euler = (
            math.radians(45) + t * (target_alpha - math.radians(45)),
            math.radians(15) + t * (target_beta_l - math.radians(15)),
            0
        )
        forearm_l.rotation_euler = (start_fore_l + t * (target_gamma - start_fore_l), 0, 0)

    elif frame <= 125:
        t = (frame - 105) / 20.0
        unfurl_factor = t

        curr_beta_r = target_beta_r + t * (math.radians(-15) - target_beta_r)
        curr_beta_l = target_beta_l + t * (math.radians(15) - target_beta_l)

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    elif frame <= 145:
        unfurl_factor = 1.0

        upper_arm_r.rotation_euler = (target_alpha, math.radians(-15), 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, math.radians(15), 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    else:
        t = (frame - 145) / 15.0
        unfurl_factor = 1.0 - t

        curr_beta_r = math.radians(-15) + t * (target_beta_r - math.radians(-15))
        curr_beta_l = math.radians(15) + t * (target_beta_l - math.radians(15))

        upper_arm_r.rotation_euler = (target_alpha, curr_beta_r, 0)
        forearm_r.rotation_euler = (target_gamma, 0, 0)

        upper_arm_l.rotation_euler = (target_alpha, curr_beta_l, 0)
        forearm_l.rotation_euler = (target_gamma, 0, 0)

    for limb in [thigh_l, thigh_r, shin_l, shin_r, foot_l, foot_r, upper_arm_l, forearm_l, upper_arm_r, forearm_r]:
        limb.keyframe_insert(data_path="rotation_euler")

    bpy.context.view_layer.update()

    wpos_r = hand_r.matrix_world.to_translation()
    wpos_l = hand_l.matrix_world.to_translation()

    scroll_roll_r.location = wpos_r
    scroll_roll_l.location = wpos_r + unfurl_factor * (wpos_l - wpos_r)

    scroll_paper.location = (scroll_roll_r.location + scroll_roll_l.location) / 2.0
    span = (scroll_roll_l.location - scroll_roll_r.location).length
    scroll_paper.scale = (max(0.01, span), 1.0, 1.0)

    node_mapping.inputs['Scale'].default_value = (peak_span, 1.0, 1.0)
    node_mapping.inputs['Location'].default_value = (-0.5 * peak_span + 0.5, 0.0, 0.0)

    scroll_roll_r.rotation_euler = (0, 0, 0)
    scroll_roll_l.rotation_euler = (0, 0, 0)
    scroll_paper.rotation_euler = (0, 0, 0)

    for prop in [scroll_roll_r, scroll_roll_l, scroll_paper]:
        prop.keyframe_insert(data_path="location")
        prop.keyframe_insert(data_path="rotation_euler")
    scroll_paper.keyframe_insert(data_path="scale")

    node_mapping.inputs['Scale'].keyframe_insert(data_path="default_value")
    node_mapping.inputs['Location'].keyframe_insert(data_path="default_value")

# ==========================================
# 9. DEFERRED GEOMETRY DECORATION (FAST)
# ==========================================
# Bake procedural displacement onto monster parts
for part in monster_parts:
    subsurf = part.modifiers.new(name="Rock_Subsurf", type='SUBSURF')
    subsurf.levels = 2
    subsurf.render_levels = 2
    displace = part.modifiers.new(name="Rock_Displace", type='DISPLACE')
    displace.texture = displace_tex
    displace.strength = 0.085

# Bake texture onto the framing peripheral boulders
for b in boulders:
    subsurf = b.modifiers.new(name="Boulder_Subsurf", type='SUBSURF')
    subsurf.levels = 1
    subsurf.render_levels = 2
    displace = b.modifiers.new(name="Boulder_Displace", type='DISPLACE')
    displace.texture = boulder_displace_tex
    displace.strength = 0.35
    displace.direction = 'NORMAL'

# ==========================================
# 10. CAMERA MOVEMENT TRACKING
# ==========================================
scene.frame_set(1)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(105)
camera.location = (0, -12, 2.5)
camera.keyframe_insert(data_path="location")

scene.frame_set(125)
camera.location = (0, -5.2, 2.0)
camera.keyframe_insert(data_path="location")

scene.frame_set(1)
print("3D Geometry Nodes grass system built successfully inside the camera view boundary!")
# Out:
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/2041999455.py:37: DeprecationWarning: 'World.use_nodes' is expected to be removed in Blender 6.0
#   world.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/2041999455.py:177: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   rock_mat.use_nodes = True
# /var/folders/wj/nxyblwq93d7ctrynx5hs3_sc0000gn/T/ipykernel_41264/2041999455.py:342: DeprecationWarning: 'Material.use_nodes' is expected to be removed in Blender 6.0
#   mat.use_nodes = True
# 3D Geometry Nodes grass system built successfully inside the camera view boundary!
